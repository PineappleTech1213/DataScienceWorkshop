# %%
library(here)
library(here)
library(readr, warn.conflicts = FALSE)
library(arrow, warn.conflicts = FALSE)
library(magrittr, warn.conflicts = FALSE)
library(stringr, warn.conflicts = FALSE)
library(dplyr, warn.conflicts = FALSE)
library(rlang, warn.conflicts = FALSE)
library(data.table, warn.conflicts = FALSE)
library(lubridate, warn.conflicts = FALSE)
library(tidyr, warn.conflicts = FALSE)
library(truveta.study)
library(dbplyr)
library(lubridate)
# Out:
# here() starts at /home/jovyan/studyrepositories/hypertensioncohorts-is5fyzbqztbebenalfbuo4boem
#
# Loading required package: DBI
#
#
# Attaching package: ‘dbplyr’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     ident, sql

# %%
# build connections 
con <- create_connection()
study <- get_study(con, title = "Hypertension Cohort")
population <- get_population(con, study, title = "Study Cohort")
snapshot <- get_latest_snapshot(con, population, finished = TRUE)
# Out:
# To sign in to Truveta, use a web browser to open the page https://login.truveta.com/activate?user_code=VLSF-TMJW.
#
# Signed in successfully.

# %%
get_data_dictionary(con,snapshot) %>% group_by(table) %>% summarise(cnt = n())
# Out:
#    table                      cnt
# 1  Claim                      13
# 2  ClaimLine                   6
# 3  ClaimLineCodes              4
# 4  Concept                     7
# 5  ConceptLink                 2
# 6  Condition                  14
# 7  ConditionCodes              4
# 8  DeviceUse                  14
# 9  Encounter                  11
# 10 ExtendedProperty            9
# 11 ImagingInstance             9
# 12 ImagingProperty            10
# 13 ImagingSeries               8
# 14 ImagingStudy                4
# 15 Immunization               14
# 16 ImmunizationCodes           4
# 17 LabResult                  16
# 18 LabResultCodes              4
# 19 Location                    4
# 20 MedicationAdministration   14
# 21 MedicationCodes             3
# 22 MedicationRequest          20
# 23 Observation                18
# 24 Patient                     2
# 25 Person                      8
# 26 PersonDeathFact             8
# 27 PersonEPCTlink              2
# 28 PersonLocation              5
# 29 PersonRace                  3
# 30 PersonTag                   3
# 31 Procedure                  10
# 32 ProcedureCodes              4
# 33 SearchResult_hypertension   5
# 34 SocialDeterminantsOfHealth  8
# 35 SocialHistory               9
# 36 Vital                      12

# %%
sql <- "select s.AttributeConceptId, c.ConceptName, count(distinct PersonId) as PatientCount , count(distinct s.Id) as RecordCount
from SocialDeterminantsOfHealth s join Concept c on (s.AttributeConceptId = c.ConceptId)
group by AttributeConceptId, ConceptName
order by 3;"

attributes_name <- load_sql_table(con,snapshot,query= sql) %>% collect()

# %%
attributes_name
# Out:
#    AttributeConceptId ConceptName
# 1  3058869            EvictionAge
# 2  3058868            CurrAddrLenOfRes
# 3  3058861            HighestEduHousehold
# 4  3058866            RaAMmbrCnt
# 5  2506717            HouseholdMotorizedPropertyRegistrationsCount
# 6  3058867            ShortLenofResBcEviction
# 7  3058865            CurrAddrMedianIncome
# 8  2506719            IndividualMotorizedPropertyRegistrationsCount
# 9  3058449            CurrAddrDwellType
# 10 3058440            CollegePastPresent
# 11 3058860            HighestEduRelatives
# 12 2506701            AddressChangeCountLast12Months
# 13 3001495            MedicationAdherenceRate
# 14 3001493            HealthcareCostPercentileRank
# 15 2506703            AddressChangeCountLast3Months
# 16 2703601            HouseholdElderlyMemberCount65+
# 17 2506707            DistanceToCloseTies
# 18 3001497            HealthManagementMotivationLevel
# 19 2506706            CurrentAddressOwnOrRent
# 20 2506702            AddressChangeCountLast1Month
# 21 2506712            FirstDegreeRelativesCount
# 22 2506715            HouseholdMembersCount
# 23 3001494            HealthcareCostRiskCategory
# 24 3001496            MedicationNonAdherenceRiskCategory
# 25 2506704            AddressChangeCountLast60Months
# 26 2506705            AddressChangeCountLast6Months
# 27 3001498            HealthManagementNonMotivationRiskCategory
#    PatientCount RecordCount
# 1  1049504      1080020
# 2  1049504      1081606
# 3  1057265      1061551
# 4  1057265      1076469
# 5  1057265      1067105
# 6  1057265      1060652
# 7  1057265      1062669
# 8  1057265      1059303
# 9  1057265      1060047
# 10 1057265      1057753
# 11 1057265      1059405
# 12 1067200      1080587
# 13 1067200      1136815
# 14 1067200      1116321
# 15 1067200      1079667
# 16 1067200      1081951
# 17 1067200      1078970
# 18 1067200      1138755
# 19 1067200      1080846
# 20 1067200      1077788
# 21 1067200      1092659
# 22 1067200      1091668
# 23 1067200      1083348
# 24 1067200      1087797
# 25 1067200      1081181
# 26 1067200      1080773
# 27 1067200      1082853

# %%
# number of patients who have at least one SDOH element
sql <- "select 'All Patients' as Type, count(distinct PersonId) as cnt
from SocialDeterminantsOfHealth
union
(select 'NonNull Patient' as Type, count(distinct PersonId) as cnt
from SocialDeterminantsOfHealth
where NormalizedValueNumeric is not NULL and EffectiveStartDateTime is not NULL);"

counts <-load_sql_table(con,snapshot,sql)%>% collect()

# %%
counts
# Out:
#   Type            cnt
# 1 All Patients    1067200
# 2 NonNull Patient 1048615

# %%
concept <- read_parquet("data/Concept.parquet")

# %%
# distribution for the normalized value concept id
sql <- "select s.AttributeConceptId, NormalizedValueConceptId, c.ConceptName, count(distinct PersonId) as PatientCount, 
count(distinct s.Id) as RecordCount
from SocialDeterminantsOfHealth s join Concept c on (s.NormalizedValueConceptId = c.ConceptId)
group by s.AttributeConceptId, NormalizedValueConceptId, ConceptName
order by 1;"

valueconcept <- load_sql_table(con,snapshot,query = sql) %>% collect() %>% select(AttributeConceptId, NormalizedValueConceptId, 
                                                                                  NormalizedValueConceptName = ConceptName,
                                                                                  PatientCount,RecordCount)%>% 
merge(., concept, by.x = "AttributeConceptId", by.y = "ConceptId",all.x = TRUE)%>%
select(AttributeConceptId, NormalizedValueConceptId, 
       NormalizedValueConceptName, AttributeName = ConceptName,PatientCount,RecordCount)
valueconcept
# Out:
#    AttributeConceptId NormalizedValueConceptId
# 1  2506706            1067558
# 2  2506706            2506674
# 3  2506706            2506675
# 4  2506706            1067561
# 5  2506707            2506677
# 6  2506707            2506676
# 7  2506707            2506678
# 8  2506707            2506679
# 9  2506707            1067561
# 10 3001494            3001527
# 11 3001494            3001519
# 12 3001494            3001528
# 13 3001494            3001517
# 14 3001494            3001518
# 15 3001496            3001521
# 16 3001496            3001520
# 17 3001496            3001522
# 18 3001496            3001523
# 19 3001496            3001524
# 20 3001498            3001530
# 21 3001498            3001526
# 22 3001498            3001525
# 23 3001498            3001531
# 24 3001498            3001529
# 25 3058440            3058441
# 26 3058440            3058442
# 27 3058440            3058443
# 28 3058449            3058452
# 29 3058449            3058453
# 30 3058449            3058455
# 31 3058449            3058450
# 32 3058449            3058454
# 33 3058449            3058457
# 34 3058449            3058456
# 35 3058860            3058447
# 36 3058860            3058658
# 37 3058860            3058446
# 38 3058860            3058448
# 39 3058860            3058445
# 40 3058861            3058445
# 41 3058861            3058448
# 42 3058861            3058447
# 43 3058861            3058658
# 44 3058861            3058446
# 45 3058867            1200406
# 46 3058867            1200405
#    NormalizedValueConceptName
# 1  Unknown
# 2  Own
# 3  Rent
# 4  No Information
# 5  25 - 100 miles
# 6  100 - 500 miles
# 7  Less than 25 miles
# 8  Over 500 miles
# 9  No Information
# 10 Low Risk
# 11 Extremely High Risk
# 12 High Risk
# 13 Well
# 14 Medium Risk
# 15 Low Non-Adherence Risk
# 16 Very Low Non-Adherence Risk
# 17 Moderate Non-Adherence Risk
# 18 High Non-Adherence Risk
# 19 Extremely High Non-Adherence Risk
# 20 High Risk
# 21 Moderate Risk
# 22 Very Low Risk
# 23 Extremely High Risk
# 24 Low Risk
# 25 No college on record
# 26 Currently attending
# 27 Attended but not currently
# 28 High rise apartment or office building
# 29 Post Office box
# 30 Street or single family dwelling
# 31 Firm or business
# 32 Rural route or highway contract
# 33 Unknown type
# 34 Other type
# 35 Graduate school
# 36 No college or graduate school on record
# 37 4 year college
# 38 Some college
# 39 2 year college
# 40 2 year college
# 41 Some college
# 42 Graduate school
# 43 No college or graduate school on record
# 44 4 year college
# 45 Yes
# 46 No
#    AttributeName                             PatientCount RecordCount
# 1  CurrentAddressOwnOrRent                    264873       268381
# 2  CurrentAddressOwnOrRent                    626987       632762
# 3  CurrentAddressOwnOrRent                    155887       158036
# 4  CurrentAddressOwnOrRent                      2978         3030
# 5  DistanceToCloseTies                         17075        17349
# 6  DistanceToCloseTies                         16925        17210
# 7  DistanceToCloseTies                        962963       972091
# 8  DistanceToCloseTies                         18121        18439
# 9  DistanceToCloseTies                         34626        35241
# 10 HealthcareCostRiskCategory                 168787       170568
# 11 HealthcareCostRiskCategory                 202208       205298
# 12 HealthcareCostRiskCategory                 277992       281723
# 13 HealthcareCostRiskCategory                 111971       112806
# 14 HealthcareCostRiskCategory                 291083       294318
# 15 MedicationNonAdherenceRiskCategory         252816       257411
# 16 MedicationNonAdherenceRiskCategory         588313       594531
# 17 MedicationNonAdherenceRiskCategory         175382       178580
# 18 MedicationNonAdherenceRiskCategory          37850        38627
# 19 MedicationNonAdherenceRiskCategory              7            7
# 20 HealthManagementNonMotivationRiskCategory   84599        85423
# 21 HealthManagementNonMotivationRiskCategory   78502        79684
# 22 HealthManagementNonMotivationRiskCategory  641533       649518
# 23 HealthManagementNonMotivationRiskCategory  148561       149238
# 24 HealthManagementNonMotivationRiskCategory   98599       100350
# 25 CollegePastPresent                         801237       801526
# 26 CollegePastPresent                           4754         4760
# 27 CollegePastPresent                         233553       233640
# 28 CurrAddrDwellType                          170267       170666
# 29 CurrAddrDwellType                           39752        39917
# 30 CurrAddrDwellType                          823484       824315
# 31 CurrAddrDwellType                               4            4
# 32 CurrAddrDwellType                            1127         1127
# 33 CurrAddrDwellType                            5878         5943
# 34 CurrAddrDwellType                             247          248
# 35 HighestEduRelatives                           437          437
# 36 HighestEduRelatives                        141322       141499
# 37 HighestEduRelatives                        311187       311605
# 38 HighestEduRelatives                        520898       521438
# 39 HighestEduRelatives                         84335        84426
# 40 HighestEduHousehold                         33370        33402
# 41 HighestEduHousehold                        362349       363215
# 42 HighestEduHousehold                            91           91
# 43 HighestEduHousehold                        581155       582263
# 44 HighestEduHousehold                         82391        82580
# 45 ShortLenofResBcEviction                     10171        10311
# 46 ShortLenofResBcEviction                   1029521      1032514

# %%
#get numeric attributes distribution
sql <- "select s.AttributeConceptId, c.ConceptName,count(distinct s.Id) as NonMissingCount,
(count(*) - count(distinct Id)) as MissingValuesCount,
avg(NormalizedValueNumeric) as Average, min(NormalizedValueNumeric) as Min,
max(NormalizedValueNumeric) as Max
from
SocialDeterminantsOfHealth s join Concept c on (s.AttributeConceptId = c.ConceptId)
where AttributeConceptId not in (3058440,3058449,2506706,3058860,3058861,3058867)
group by AttributeConceptId,ConceptName
order by 1;"

numeric_attr <- load_sql_table(con,snapshot, query =sql) %>% collect()
numeric_attr
# Out:
#    AttributeConceptId ConceptName
# 1  2506701            AddressChangeCountLast12Months
# 2  2506702            AddressChangeCountLast1Month
# 3  2506703            AddressChangeCountLast3Months
# 4  2506704            AddressChangeCountLast60Months
# 5  2506705            AddressChangeCountLast6Months
# 6  2506707            DistanceToCloseTies
# 7  2506712            FirstDegreeRelativesCount
# 8  2506715            HouseholdMembersCount
# 9  2506717            HouseholdMotorizedPropertyRegistrationsCount
# 10 2506719            IndividualMotorizedPropertyRegistrationsCount
# 11 2703601            HouseholdElderlyMemberCount65+
# 12 3001493            HealthcareCostPercentileRank
# 13 3001494            HealthcareCostRiskCategory
# 14 3001495            MedicationAdherenceRate
# 15 3001496            MedicationNonAdherenceRiskCategory
# 16 3001497            HealthManagementMotivationLevel
# 17 3001498            HealthManagementNonMotivationRiskCategory
# 18 3058865            CurrAddrMedianIncome
# 19 3058866            RaAMmbrCnt
# 20 3058868            CurrAddrLenOfRes
# 21 3058869            EvictionAge
#    NonMissingCount MissingValuesCount Average      Min     Max
# 1  1080587         0                      0.122356  0.0000     25.0000
# 2  1077788         0                      0.003027  0.0000      4.0000
# 3  1079667         0                      0.021208  0.0000      6.0000
# 4  1081181         0                      0.698655  0.0000    100.0000
# 5  1080773         0                      0.059176  0.0000     10.0000
# 6  1078970         0                      0.067757 -1.0000      3.0000
# 7  1092659         0                      9.808893  0.0000    100.0000
# 8  1091668         0                      2.944950  1.0000    255.0000
# 9  1067105         0                      2.550157  0.0000    228.0000
# 10 1059303         0                      1.415146  0.0000     25.0000
# 11 1081951         0                      0.957038  0.0000    188.0000
# 12 1116321         0                     77.886624  1.0000    100.0000
# 13 1083348         0                      3.278139  1.0000      5.0000
# 14 1136815         0                     79.433255 28.5293     93.7817
# 15 1087797         0                      1.683230  1.0000      5.0000
# 16 1138755         0                     44.182673  0.0000     91.4257
# 17 1082853         0                      2.045785  1.0000      5.0000
# 18 1062669         0                  65786.155261 -1.0000 253515.0000
# 19 1076469         0                     11.202611  0.0000    255.0000
# 20 1081606         0                    199.104836 -1.0000    959.0000
# 21 1080020         0                     11.775000 -1.0000    415.0000

# %%
# get distirbution of categorical attributes

sql <-  "select s.AttributeConceptId, s.NormalizedValueConceptId, c.ConceptName as 'AttributeName',
count(distinct s.Id) as n from
SocialDeterminantsOfHealth s join Concept c on (s.AttributeConceptId = c.ConceptId)
where AttributeConceptId in (3058440,3058449,2506706,3058860,3058861,3058867)
group by AttributeConceptId,NormalizedValueConceptId,ConceptName;"
category_attr <- load_sql_table(con,snapshot,query = sql)%>% collect() %>% merge(.,concept,by.x = "NormalizedValueConceptId",
                                                                                 by.y = "ConceptId", all.x = TRUE)%>%
select(AttributeConceptId, NormalizedValueConceptId,AttributeName, ValueName = ConceptName,n)%>%
arrange(AttributeConceptId, NormalizedValueConceptId)
category_attr
# Out:
#    AttributeConceptId NormalizedValueConceptId AttributeName
# 1  2506706            1067558                  CurrentAddressOwnOrRent
# 2  2506706            1067561                  CurrentAddressOwnOrRent
# 3  2506706            2506674                  CurrentAddressOwnOrRent
# 4  2506706            2506675                  CurrentAddressOwnOrRent
# 5  2506706                 NA                  CurrentAddressOwnOrRent
# 6  3058440            3058441                  CollegePastPresent
# 7  3058440            3058442                  CollegePastPresent
# 8  3058440            3058443                  CollegePastPresent
# 9  3058440                 NA                  CollegePastPresent
# 10 3058449            3058450                  CurrAddrDwellType
# 11 3058449            3058452                  CurrAddrDwellType
# 12 3058449            3058453                  CurrAddrDwellType
# 13 3058449            3058454                  CurrAddrDwellType
# 14 3058449            3058455                  CurrAddrDwellType
# 15 3058449            3058456                  CurrAddrDwellType
# 16 3058449            3058457                  CurrAddrDwellType
# 17 3058449                 NA                  CurrAddrDwellType
# 18 3058860            3058445                  HighestEduRelatives
# 19 3058860            3058446                  HighestEduRelatives
# 20 3058860            3058447                  HighestEduRelatives
# 21 3058860            3058448                  HighestEduRelatives
# 22 3058860            3058658                  HighestEduRelatives
# 23 3058861            3058445                  HighestEduHousehold
# 24 3058861            3058446                  HighestEduHousehold
# 25 3058861            3058447                  HighestEduHousehold
# 26 3058861            3058448                  HighestEduHousehold
# 27 3058861            3058658                  HighestEduHousehold
# 28 3058867            1200405                  ShortLenofResBcEviction
# 29 3058867            1200406                  ShortLenofResBcEviction
# 30 3058867                 NA                  ShortLenofResBcEviction
#    ValueName                               n
# 1  Unknown                                  268381
# 2  No Information                             3030
# 3  Own                                      632762
# 4  Rent                                     158036
# 5  NA                                        18637
# 6  No college on record                     801526
# 7  Currently attending                        4760
# 8  Attended but not currently               233640
# 9  NA                                        17827
# 10 Firm or business                              4
# 11 High rise apartment or office building   170666
# 12 Post Office box                           39917
# 13 Rural route or highway contract            1127
# 14 Street or single family dwelling         824315
# 15 Other type                                  248
# 16 Unknown type                               5943
# 17 NA                                        17827
# 18 2 year college                            84426
# 19 4 year college                           311605
# 20 Graduate school                             437
# 21 Some college                             521438
# 22 No college or graduate school on record  141499
# 23 2 year college                            33402
# 24 4 year college                            82580
# 25 Graduate school                              91
# 26 Some college                             363215
# 27 No college or graduate school on record  582263
# 28 No                                      1032514
# 29 Yes                                       10311
# 30 NA                                        17827

# %%
# number of patietns with SDOH data element in their absolute year time
index_date <- read_parquet("data/index_date.parquet")
head(index_date)


sql <- "select year(s.EffectiveStartDateTime) as Year,s.Id as SDOHId,sr.*
from
SocialDeterminantsOfHealth s join (
Select PersonId, RecordedDateTime as 'IndexDate', AbsoluteEffectiveDateTime as 'AbsoluteIndexYM'
from(
select PersonId, row_number() over (partition by PersonId order by RecordedDateTime) as 'rownum', 
RecordedDateTime, AbsoluteEffectiveDateTime
from SearchResult_hypertension
group by PersonId, RecordedDateTime, AbsoluteEffectiveDateTime)  as t
where t.rownum =1) as sr on (s.PersonId = sr.PersonId)
order by 1;"


idx_record <- load_sql_table(con,snapshot,query= sql) %>% collect()
head(idx_record,10)
# Out:
#   PersonId                             IndexDate  AbsoluteIndexYM ShiftDays
# 1 00000608-8ba0-385f-c781-4ac002edbff8 2018-03-05 2019-04         392
# 2 000009b2-284d-b26b-3e1e-e97dc61cc275 2018-02-22 2019-04         403
# 3 000018f2-ff85-1ebe-ed48-cef0e95b650f 2017-02-25 2019-02         706
# 4 00002dd6-b955-6eea-4fb9-b3605de42dff 2017-05-11 2019-03         659
# 5 00003074-3a64-0fd9-d250-930e7cf7ddaa 2017-11-20 2019-01         407
# 6 000037e4-3401-af14-5c44-15dc735b500b 2017-07-06 2019-06         695
#    Year SDOHId
# 1  NA   393f792a-a3f0-b3ad-e9db-55351c3061c8
# 2  NA   c48b5039-4669-c99c-fbdb-bd3047808874
# 3  NA   952dddec-cb2d-c479-067d-ddf60af75e67
# 4  NA   1e3fc080-d65e-3fc0-fd77-9144ff0fb444
# 5  NA   f70d73ec-10df-9bdc-0386-964bd1eaed53
# 6  NA   823a7e73-35ab-4fd6-056b-18d8f0a4769f
# 7  NA   d4411081-2a20-cb0c-d184-aea57bd217f1
# 8  NA   b5bc1f8d-88ef-6ec5-fd69-445428fbd63b
# 9  NA   890fa8e3-5ecf-42dc-0d5c-d21ebdd43269
# 10 NA   9b487dcb-f564-5e1b-b80b-56df3116f7fc
#    PersonId                             IndexDate  AbsoluteIndexYM
# 1  2ea78d83-3207-f00b-9903-5866286bf7a6 2017-05-08 2019-03
# 2  2ea78d83-3207-f00b-9903-5866286bf7a6 2017-05-08 2019-03
# 3  904c2761-714b-adbe-e6e1-4dec29a1b78b 2017-10-28 2019-01
# 4  db9ef85e-e350-a564-f59f-235cb2735415 2017-12-20 2019-05
# 5  2ea78d83-3207-f00b-9903-5866286bf7a6 2017-05-08 2019-03
# 6  2ea78d83-3207-f00b-9903-5866286bf7a6 2017-05-08 2019-03
# 7  904c2761-714b-adbe-e6e1-4dec29a1b78b 2017-10-28 2019-01
# 8  db9ef85e-e350-a564-f59f-235cb2735415 2017-12-20 2019-05
# 9  2ea78d83-3207-f00b-9903-5866286bf7a6 2017-05-08 2019-03
# 10 2ea78d83-3207-f00b-9903-5866286bf7a6 2017-05-08 2019-03

# %%
tables <- list(category_attr,numeric_attr,attributes_name,counts,idx_record)
saveRDS(tables, "data/tables.rds")
#read it in next time
#tables <- readRDS("data/tables.rds")

# %%
idx_record %>% group_by(AbsoluteIndexYM) %>% summarise(cnt = n())
# Out:
#    AbsoluteIndexYM cnt
# 1  2019-01         6745886
# 2  2019-02         3997206
# 3  2019-03         3466142
# 4  2019-04         2827390
# 5  2019-05         2400642
# 6  2019-06         1940611
# 7  2019-07         1604472
# 8  2019-08         1426229
# 9  2019-09         1283302
# 10 2019-10         1337215
# 11 2019-11         1107273
# 12 2019-12         1062191

# %%
idx_record %>% group_by(year(IndexDate)) %>% summarise(cnt = n())
# Out:
#   year(IndexDate) cnt
# 1 2016                1192
# 2 2017            19575908
# 3 2018             9621432
# 4 2019                  27
